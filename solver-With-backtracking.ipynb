# %% [markdown]
# ### soduku solver
#
# ##### About Sudoku
# Sudoku is a logic-based, combinatorial number-placement puzzle. The objective is to fill a 9x9 grid with digits so that each column, each row, and each of the nine 3x3 subgrids that compose the grid (also called "boxes", "blocks", or "regions") contains all of the digits from 1 to 9.
#
# ##### About This solver
#
# In this project, we use a technique called constraint propagation together with backtracking search to make an agent that only considers reasonable solution candidates and efficiently solves any Sudoku puzzle. This approach appears in many classical AI problems, and the solution techniques have been extended and applied to diverse problems in bioinformatics, logistics, and operations research. In this project you will demonstrate some basic algorithms knowledge, and learn to use constraint satisfaction to solve general problems
#
# Useful resource: https://leetcode.com/problems/sudoku-solver/

# %%
board =[["5","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]]
#board = [[".","4",".",".",".","2",".",".","9"],[".",".","8","4","7",".",".",".","5"],[".",".",".",".",".","6",".","7","."],[".","6",".","9","1",".",".","5","."],["3",".",".",".",".",".",".",".","8"],[".",".",".",".",".","7",".",".","."],[".","9",".","5","4",".",".","1","."],[".",".","6",".",".",".","9",".","."],[".",".",".","2",".",".",".",".","."]]
board = [["8",".",".","1",".",".",".","7","."],[".","2",".",".","4",".","8",".","."],[".","6",".","7",".",".",".",".","."],[".",".",".","4","7",".","9",".","8"],["2","4",".",".","8",".",".",".","."],[".","3","8",".",".",".",".",".","5"],[".","8",".","6",".","4","1",".","."],["9",".",".",".",".","7","2",".","4"],[".",".","5","8","1",".",".",".","6"]]
def checkNumbers(num, row, col):
    for x in range(9):
        if board[row][x] == num:
            return True     
    for x in range(9):
        if board[x][col] == num:
            return True
    startRow = row - row % 3
    startCol = col - col % 3
    for i in range(3):
        for j in range(3):
            if board[i + startRow][j + startCol] == num:
                return True
    return False

def solve():
    range = [0,1,2,3,4,5,6,7,8]
    for x in range:
        for y in range:
            if('.' == board[x][y]):
                for num in [1,2,3,4,5,6,7,8,9]:
                    if not checkNumbers(str(num), x, y):
                        board[x][y]=str(num)
                        print("trying"+str(num))
                        if solve():
                            print(str(num)+" is a right guess for "+"row "+str(x)+" column "+str(y))
                            return True
                        else:
                            print(str(num)+" is A bad try")
                            board[x][y]='.'
                return False
    return True

print(board)
print(solve())
print(board)
# Out:
# [['8', '.', '.', '1', '.', '.', '.', '7', '.'], ['.', '2', '.', '.', '4', '.', '8', '.', '.'], ['.', '6', '.', '7', '.', '.', '.', '.', '.'], ['.', '.', '.', '4', '7', '.', '9', '.', '8'], ['2', '4', '.', '.', '8', '.', '.', '.', '.'], ['.', '3', '8', '.', '.', '.', '.', '.', '5'], ['.', '8', '.', '6', '.', '4', '1', '.', '.'], ['9', '.', '.', '.', '.', '7', '2', '.', '4'], ['.', '.', '5', '8', '1', '.', '.', '.', '6']]
# trying5
# trying3
# trying2
# trying6
# trying4
# trying9
# trying1
# trying7
# trying3
# trying5
# trying6
# 6 is A bad try
# 5 is A bad try
# trying9
# trying5
# 5 is A bad try
# trying6
# 6 is A bad try
# 9 is A bad try
# 3 is A bad try
# trying5
# trying3
# trying6
# 6 is A bad try
# 3 is A bad try
# trying9
# trying3
# 3 is A bad try
# trying6
# trying3
# trying4
# trying9
# trying3
# trying8
# trying5
# trying1
# trying2
# trying5
# trying1
# trying6
# trying2
# trying3
# 3 is A bad try
# 2 is A bad try
# trying3
# trying2
# 2 is A bad try
# 3 is A bad try
# ...
